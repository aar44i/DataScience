# %%
import pandas as pd
rt = pd.read_csv('ratings (6).xls')
rt.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
mv = pd.read_csv('movies (6).xls')
mv.head(50)
# Out:
#     movieId                                              title  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 2         3                            Grumpier Old Men (1995)
# 3         4                           Waiting to Exhale (1995)
# 4         5                 Father of the Bride Part II (1995)
# 5         6                                        Heat (1995)
# 6         7                                     Sabrina (1995)
# 7         8                                Tom and Huck (1995)
# 8         9                                Sudden Death (1995)
# 9        10                                   GoldenEye (1995)
# 10       11                     American President, The (1995)
# 11       12                 Dracula: Dead and Loving It (1995)
# 12       13                                       Balto (1995)
# 13       14                                       Nixon (1995)
# ...

# %%
mv.movieId.count()
# Out:
# 9742

# %% [markdown]
# Какое минимальное значение принимает выставленная оценка в датасете ratings?

# %%
rt.rating.min()
# Out:
# 0.5

# %%
len(rt) == len(joined)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4b0d01ef439b> in <module>
# ----> 1 len(rt) == len(joined)
#
# NameError: name 'joined' is not defined

# %%
joinedd = rt.merge(mv, on='movieId', how='left')
joinedd.head(30)
# Out:
#     userId  movieId  rating  timestamp  \
# 0        1        1     4.0  964982703
# 1        1        3     4.0  964981247
# 2        1        6     4.0  964982224
# 3        1       47     5.0  964983815
# 4        1       50     5.0  964982931
# 5        1       70     3.0  964982400
# 6        1      101     5.0  964980868
# 7        1      110     4.0  964982176
# 8        1      151     5.0  964984041
# 9        1      157     5.0  964984100
# 10       1      163     5.0  964983650
# 11       1      216     5.0  964981208
# 12       1      223     3.0  964980985
# 13       1      231     5.0  964981179
# 14       1      235     4.0  964980908
# 15       1      260     5.0  964981680
# 16       1      296     3.0  964982967
# 17       1      316     3.0  964982310
# 18       1      333     5.0  964981179
# 19       1      349     4.0  964982563
# 20       1      356     4.0  964980962
# 21       1      362     5.0  964982588
# 22       1      367     4.0  964981710
# ...

# %%
rt.merge(mv, how = 'left', on = 'movieId')
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %% [markdown]
# сброс всех повторяющихся значений

# %%
mv.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
mv.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

# %%
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# %%
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %%
items_df.head(15)
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
purchase_df.head(15)
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
items_df.merge(purchase_df, how = 'right', on = 'item_id')
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung         54.0          101  13900
# 1   849734       LG         33.0          101   5330
# 2   132223    Apple        122.0          101  38200
# 3   573943    Apple         18.0          112  49990
# 4    19475       LG        102.0          121   9890
# 5  3294095    Apple         43.0          145  33000
# 6   382043  Samsung         77.0          145  67500
# 7   302948  Samsung        143.0          145  34500
# 8   100132       LG         60.0          221  11400
# 9   103845      NaN          NaN          145  89900

# %%
items_df.merge(purchase_df, how = 'left', on = 'item_id')
# Out:
#    item_id   vendor  stock_count  purchase_id    price
# 0   417283  Samsung           54        101.0  13900.0
# 1   849734       LG           33        101.0   5330.0
# 2   132223    Apple          122        101.0  38200.0
# 3   573943    Apple           18        112.0  49990.0
# 4    19475       LG          102        121.0   9890.0
# 5  3294095    Apple           43        145.0  33000.0
# 6   382043  Samsung           77        145.0  67500.0
# 7   302948  Samsung          143        145.0  34500.0
# 8   100132       LG           60        221.0  11400.0
# 9   312394      ZTE           19          NaN      NaN

# %%
mergeddd = items_df.merge(purchase_df, how = 'inner', on = 'item_id')
mergeddd
#merged.item_id.count()
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %% [markdown]
# Посчитайте объем выручки для каждой модели, которую можно получить, распродав все остатки на складе. Модель с каким item_id имеет максимальное значение выручки после распродажи остатков? Ответ дайте в виде целого числа.
#
# Примечание: перемножение столбцов датафрейма можно производить разными способами, но самый простой - перемножение "в лоб" вида df['col1'] = df['col2'] * df['col3']. Для присоединения новых данных к датафрейму тоже можно использовать различные методы, включая функцию .append(), которая позволяет присоединять к датафрейму другой датафрейм, серии или словари.

# %%
#profit = pd.DataFrame(merged['purchase_id'] * merged['price'])
#merged.append(merged['profit'] == merged['purchase_id'] * merged['price'])
mergeddd.insert(4, 'profit', mergedd['stock_count'] * mergedd['price'])
mergeddd
# mergedd[mergedd.profit.max()].item_id
# Out:
#    item_id   vendor  stock_count  purchase_id   profit  price
# 0   417283  Samsung           54          101   750600  13900
# 1   849734       LG           33          101   175890   5330
# 2   132223    Apple          122          101  4660400  38200
# 3   573943    Apple           18          112   899820  49990
# 4    19475       LG          102          121  1008780   9890
# 5  3294095    Apple           43          145  1419000  33000
# 6   382043  Samsung           77          145  5197500  67500
# 7   302948  Samsung          143          145  4933500  34500
# 8   100132       LG           60          221   684000  11400

# %%
mergedd.profit
# Out:
# 0    1403900
# 1     538330
# 2    3858200
# 3    5598880
# 4    1196690
# 5    4785000
# 6    9787500
# 7    5002500
# 8    2519400
# Name: profit, dtype: int64

# %%
mergeddd[mergedd.profit == mergedd.profit.max()]
# ft[ft.Nationality == 'Brazil'].Penalties.sum()
# mergedd.profit.max()
# Out:
#    item_id   vendor  stock_count  purchase_id   profit  price
# 6   382043  Samsung           77          145  5197500  67500

# %% [markdown]
# Посчитайте итоговую выручку из прошлого задания по всем моделям. Ответ дайте в виде целого числа.

# %%
mergeddd.profit.sum()
# Out:
# 19729490

# %%
import os

# %%
path = 'C:/Users/gorba/DataSciense/WORK/SkillFactory/data_movies'
import os
files = os.listdir(path) 
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %%
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
data
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# Напишите цикл, который собирает содержимое файлов папки data в единый датафрейм data.
#
# Сколько строк в датафрейме data?

# %%
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
i = 0
txt = [x for x in files]# if x.endswith('.txt')]
for x in txt:
    temp = pd.read_csv( os.path.join(path, x), names = ['userId', 'movieId', 'rating', 'timestamp'] )
    i += 1
    data = pd.concat([data, temp])
data.userId.count()
# Out:
# 100004

# %% [markdown]
# Сколько раз была выставлена низшая оценка 0.5 в наших рейтингах? Используйте файл ratings.csv.

# %%
rt = pd.read_csv('ratings (6).xls')
rt
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rt[rt.rating == 0.5].userId.count()
# Out:
# 1370

# %% [markdown]
# Найдите в датафрейме movies фильм с movieId=3456.
#
# Какой у него год выпуска?
#
# P. S. Попробуйте найти movieId этого фильма в датафрейме ratings. Это будет ключом к ответу на следующее задание.

# %%
movieId=3456

# %%
joinedd[joinedd.movieId == 3456]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp, title, genres]
# Index: []
