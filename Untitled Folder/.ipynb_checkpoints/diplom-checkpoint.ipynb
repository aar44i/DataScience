# %%
import pandas as pd
from os import listdir 
import openpyxl

# %%
path = 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/'
files = listdir(path) 
# files
ww = []

# %%
for r, d, f in os.walk(path):
    for file in f:
        if file.endswith(".txt"):
#             print(os.path.join(r + '/' + file))
            ww.append(os.path.join(r + '/' + file))
# len(ww)
pd.DataFrame(ww)
# Out:
#                                                      0
# 0    C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 1    C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 2    C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 3    C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 4    C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# ..                                                 ...
# 850  C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 851  C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 852  C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 853  C:/Users/gorba/Desktop/Univercity/3 course/Cou...
# 854  C:/Users/gorba/Desktop/Univercity/3 course/Cou...
#
# [855 rows x 1 columns]

# %%
# r=root, d=directories, f = files
ways = []
for r, d, f in os.walk(path):
    for fld in folder:
        for file in f:
            if file.endswith(".txt"):
#                 print(os.path.join(path + fld + '/' +  file)) 
                ways.append(os.path.join(path + fld + '/' +  file))
#                 print(fld)
    #                 print(d)
#                     file
#                     df = pd.read_excel(path + fld + '/' + file)
ways
# Out:
# ['C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/AllGrWat.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/in.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/inmeteo.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/in_rean.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/in_rean_ymd.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/pavs.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/Total.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Vl/AllGrWat.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Vl/in.txt',
#  'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Vl/inmeteo.txt',
# ...

# %%
ways = list(dict.fromkeys(ways))
print(ways)
# mylist = ["a", "b", "a", "c", "c"]
# mylist = list(dict.fromkeys(mylist))
# print(mylist)
# Out:
# ['C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/AllGrWat.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Ko/Total.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Vl/AllGrWat.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Klz-Vl/Total.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Mok-Te/AllGrWat.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Mok-Te/Total.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Mol-Us/AllGrWat.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Mol-Us/Total.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Msk-Zv/AllGrWat.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/Msk-Zv/Total.txt', 'C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3
# ...

# %%
ss=openpyxl.load_workbook("C:/Users/gorba/Desktop/Univercity/3 course/CourseWork/GrWat 3.0.M/files/biba.xlsx")
#printing the sheet names
ss_sheet = ss['pipa']
ss_sheet.title = 'Fruit'
ss.save("biba.xlsx")

# %%
# r=root, d=directories, f = files
for r, d, f  in os.walk(path): # создаем вектор с названиями папок в которых лежат нужные фаилы
    folders.append(d) 
folder = folders[0]
folder # вектор с названиями папок
# Out:
# ['Klz-Ko',
#  'Klz-Vl',
#  'Mok-Te',
#  'Mol-Us',
#  'Msk-Zv',
#  'Oka-Bl',
#  'Oka-Go',
#  'Oka-Ka',
#  'Oka-Kh',
#  'Oka-Mu',
#  'Oka-Po',
#  'Pro-Bi',
#  'Prt-Sp',
#  'Sur-Po',
#  'Tvr-Md',
#  'Ugr-Tv',
#  'Upa-Or',
#  'Zhi-Kz',
#  'Zhu-Mc']

# %%
len(folder)
# Out:
# 19
